# %%
# !pip install scipy

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------
# absl-py                            0.10.0
# aiofiles                           0.5.0
# aiohttp                            3.6.2
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.6
# anaconda-project                   0.8.2
# appdirs                            1.4.4
# asn1crypto                         1.3.0
# astroid                            2.1.0
# astropy                            3.1
# astunparse                         1.6.3
# async-generator                    1.10
# async-timeout                      3.0.1
# atomicwrites                       1.2.1
# attrs                              19.3.0
# Babel                              2.6.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.6.3
# ...

# %%
import numpy as np
from keras.models import Sequence

# %%
import keras as k

# %%
help(k)
# Out:
# Help on package keras:
#
# NAME
#     keras
#
# PACKAGE CONTENTS
#     activations
#     applications (package)
#     backend
#     callbacks
#     constraints
#     datasets (package)
#     engine (package)
#     initializers
#     layers (package)
#     losses
#     metrics
#     models
#     objectives
#     optimizers (package)
#     preprocessing (package)
#     regularizers
#     utils (package)
#     wrappers (package)
#
# VERSION
#     2.4.3
#
# FILE
#     c:\users\bhawa\anaconda3\lib\site-packages\keras\__init__.py

# %%
help(k.preprocessing)
# Out:
# Help on package keras.preprocessing in keras:
#
# NAME
#     keras.preprocessing
#
# PACKAGE CONTENTS
#     image
#     sequence
#     text
#
# FILE
#     c:\users\bhawa\anaconda3\lib\site-packages\keras\preprocessing\__init__.py

# %%
help(k.layers)
# Out:
# Help on package keras.layers in keras:
#
# NAME
#     keras.layers
#
# PACKAGE CONTENTS
#     advanced_activations
#     convolutional
#     convolutional_recurrent
#     core
#     cudnn_recurrent
#     embeddings
#     experimental (package)
#     local
#     merge
#     noise
#     normalization
#     pooling
#     recurrent
#     wrappers
#
# FILE
#     c:\users\bhawa\anaconda3\lib\site-packages\keras\layers\__init__.py

# %%
dir(k.layers)
# Out:
# ['AbstractRNNCell',
#  'Activation',
#  'ActivityRegularization',
#  'Add',
#  'AdditiveAttention',
#  'AlphaDropout',
#  'Attention',
#  'Average',
#  'AveragePooling1D',
#  'AveragePooling2D',
#  'AveragePooling3D',
#  'AvgPool1D',
#  'AvgPool2D',
#  'AvgPool3D',
#  'BatchNormalization',
#  'Bidirectional',
#  'Concatenate',
#  'Conv1D',
#  'Conv1DTranspose',
#  'Conv2D',
#  'Conv2DTranspose',
#  'Conv3D',
#  'Conv3DTranspose',
#  'ConvLSTM2D',
#  'Convolution1D',
#  'Convolution1DTranspose',
#  'Convolution2D',
#  'Convolution2DTranspose',
#  'Convolution3D',
#  'Convolution3DTranspose',
#  'Cropping1D',
#  'Cropping2D',
#  'Cropping3D',
#  'Dense',
#  'DenseFeatures',
#  'DepthwiseConv2D',
#  'Dot',
#  'Dropout',
#  'ELU',
#  'Embedding',
#  'Flatten',
#  'GRU',
#  'GRUCell',
#  'GaussianDropout',
#  'GaussianNoise',
#  'GlobalAveragePooling1D',
#  'GlobalAveragePooling2D',
#  'GlobalAveragePooling3D',
#  'GlobalAvgPool1D',
#  'GlobalAvgPool2D',
#  'GlobalAvgPool3D',
# ...

# %%
from keras.models import Model, Sequential

# %%
from keras.layers import BatchNormalization, Activation, AveragePooling3D, Conv3D, Dense, Dropout, Flatten, GRU, GlobalAvgPool3D, LSTM, MaxPooling3D, ReLU, Softmax, TimeDistributed

# %%
dir(k.layers.convolutional)
# Out:
# ['AveragePooling1D',
#  'AveragePooling2D',
#  'AveragePooling3D',
#  'Conv1D',
#  'Conv2D',
#  'Conv2DTranspose',
#  'Conv3D',
#  'Conv3DTranspose',
#  'Convolution1D',
#  'Convolution2D',
#  'Convolution2DTranspose',
#  'Convolution3D',
#  'Cropping1D',
#  'Cropping2D',
#  'Cropping3D',
#  'Deconv2D',
#  'Deconv3D',
#  'Deconvolution2D',
#  'Deconvolution3D',
#  'DepthwiseConv2D',
#  'MaxPooling1D',
#  'MaxPooling2D',
#  'MaxPooling3D',
#  'SeparableConv1D',
#  'SeparableConv2D',
#  'SeparableConvolution1D',
#  'SeparableConvolution2D',
#  'UpSampling1D',
#  'UpSampling2D',
#  'UpSampling3D',
#  'ZeroPadding1D',
#  'ZeroPadding2D',
#  'ZeroPadding3D',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %%
help(MaxPooling3D)
# Out:
# Help on class MaxPooling3D in module tensorflow.python.keras.layers.pooling:
#
# class MaxPooling3D(Pooling3D)
#  |  MaxPooling3D(*args, **kwargs)
#  |
#  |  Max pooling operation for 3D data (spatial or spatio-temporal).
#  |
#  |  Arguments:
#  |    pool_size: Tuple of 3 integers,
#  |      factors by which to downscale (dim1, dim2, dim3).
#  |      `(2, 2, 2)` will halve the size of the 3D input in each dimension.
#  |    strides: tuple of 3 integers, or None. Strides values.
#  |    padding: One of `"valid"` or `"same"` (case-insensitive).
#  |    data_format: A string,
#  |      one of `channels_last` (default) or `channels_first`.
#  |      The ordering of the dimensions in the inputs.
#  |      `channels_last` corresponds to inputs with shape
#  |      `(batch, spatial_dim1, spatial_dim2, spatial_dim3, channels)`
#  |      while `channels_first` corresponds to inputs with shape
#  |      `(batch, channels, spatial_dim1, spatial_dim2, spatial_dim3)`.
# ...

# %%
model=Sequential()
model.add(Conv3D(1,(3,3,3), activation="relu", input_shape=(21,90,90,3)))
model.add(MaxPooling3D(pool_size=(1,2,2)))
model.add(Dropout(0.25))
model.add(Conv3D(1,(3,3,3), activation="relu"))


model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_29 (Conv3D)           (None, 19, 88, 88, 1)     82
# _________________________________________________________________
# max_pooling3d_15 (MaxPooling (None, 19, 44, 44, 1)     0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 19, 44, 44, 1)     0
# _________________________________________________________________
# conv3d_30 (Conv3D)           (None, 17, 42, 42, 1)     28
# ...
# Total params: 110
# Trainable params: 110
# Non-trainable params: 0
# _________________________________________________________________
